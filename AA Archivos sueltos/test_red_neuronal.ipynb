# %%
import pandas as pd
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_circles

# %%
df = pd.read_csv('test.csv')

# %%
df.Gender= df.Gender.map({'Female': 0, 'Male': 1})
df['Customer Type']=df['Customer Type'].map({'Loyal Customer': 0, 'disloyal Customer':1})
df['Type of Travel']=df['Type of Travel'].map({'Business travel': 0, 'Personal Travel':1})
df.Class=df.Class.map({'Eco': 0, 'Business':1,'No servicio tel':1})
df.satisfaction=df.satisfaction.map({'satisfied': 0, 'neutral or dissatisfied':1})

# %%
df=df.drop('Unnamed: 0', axis=1)
df=df.drop('id', axis=1)

# %%
df.fillna(df.mean())
df=df.fillna(df.mean(),axis=0)

# %%
df.describe()
# Out:
#              Gender  Customer Type           Age  Type of Travel  \
# count  25976.000000   25976.000000  25976.000000    25976.000000
# mean       0.492917       0.184747     39.620958        0.305590
# std        0.499959       0.388100     15.135685        0.460666
# min        0.000000       0.000000      7.000000        0.000000
# 25%        0.000000       0.000000     27.000000        0.000000
# 50%        0.000000       0.000000     40.000000        0.000000
# 75%        1.000000       0.000000     51.000000        1.000000
# max        1.000000       1.000000     85.000000        1.000000
#
#               Class  Flight Distance  Inflight wifi service  \
# count  25976.000000     25976.000000           25976.000000
# mean       0.519348      1193.788459               2.724746
# std        0.480846       998.683999               1.335384
# min        0.000000        31.000000               0.000000
# 25%        0.000000       414.000000               2.000000
# ...

# %%
df

# %%
train_x = df.drop('Class', axis=1)
train_y = df['Class']

# %%
train_y
# Out:
# 0        0.0
# 1        1.0
# 2        0.0
# 3        1.0
# 4        0.0
#         ...
# 25971    1.0
# 25972    1.0
# 25973    0.0
# 25974    1.0
# 25975    0.0
# Name: Class, Length: 25976, dtype: float64

# %%
classifier = MLPClassifier(hidden_layer_sizes=(10,5), activation='logistic', solver='sgd', learning_rate='adaptive', learning_rate_init=0.05)

# %%
classifier.fit(train_x, train_y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-e76fe8927399> in <module>
# ----> 1 classifier.fit(train_x, train_y)
#
# c:\disco particon\algoritmica avanzada\virtual enviroment\examen parcial 2\parcial2_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in fit(self, X, y)
#    1025         self : returns a trained MLP model.
#    1026         """
# -> 1027         return self._fit(X, y, incremental=(self.warm_start and
#    1028                                             hasattr(self, "classes_")))
#    1029
#
# c:\disco particon\algoritmica avanzada\virtual enviroment\examen parcial 2\parcial2_env\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py in _fit(self, X, y, incremental)
#     324                              hidden_layer_sizes)
#     325
# --> 326         X, y = self._validate_input(X, y, incremental)
# ...

# %%
print(f"Coeficiente de Pérdida: {classifier.loss_}")
print(f"Precisión de la Red: {classifier.score(train_x, train_y)}")
print(f"Número de épocas de estudio: {classifier.n_iter_}")
